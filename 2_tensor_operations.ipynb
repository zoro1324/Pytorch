# %%
import torch 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
tensor_1 = torch.randn(
    size=(3,3),
    device=device,
    requires_grad=False
)

tensor_2 = torch.rand_like(
    input=tensor_1
)

print(f"Tensor 1 : {tensor_1} \nTensor 2 : {tensor_2}")
# Out:
# Tensor 1 : tensor([[ 0.5800,  0.5462, -1.0354],
#         [ 0.0526,  0.6979,  0.1218],
#         [ 0.6995, -0.8905, -1.8050]], device='cuda:0')
# Tensor 2 : tensor([[0.2934, 0.5486, 0.0280],
#         [0.6293, 0.6286, 0.7797],
#         [0.3009, 0.0012, 0.7718]], device='cuda:0')

# %%
# %%time
torch.matmul(tensor_1,tensor_2)
# Out:
# CPU times: total: 0 ns
# Wall time: 996 μs
# tensor([[ 0.2024,  0.6603, -0.3570],
#         [ 0.4913,  0.4677,  0.6396],
#         [-0.8982, -0.1782, -2.0678]], device='cuda:0')

# %%
# %%time
tensor_1*tensor_2
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# tensor([[ 1.7021e-01,  2.9969e-01, -2.8953e-02],
#         [ 3.3127e-02,  4.3872e-01,  9.4977e-02],
#         [ 2.1047e-01, -1.0975e-03, -1.3931e+00]], device='cuda:0')
