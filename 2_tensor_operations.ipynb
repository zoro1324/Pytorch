# %%
import torch 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
tensor_1 = torch.randn(
    size=(3,3),
    device=device,
    requires_grad=False
)

tensor_2 = torch.rand_like(
    input=tensor_1
)

print(f"Tensor 1 : {tensor_1} \nTensor 2 : {tensor_2}")
# Out:
# Tensor 1 : tensor([[ 0.2166,  0.6120, -1.9486],
#         [ 0.8940, -0.2208, -0.5906],
#         [ 0.0649, -1.7398, -0.3163]], device='cuda:0')
# Tensor 2 : tensor([[0.3337, 0.9805, 0.7658],
#         [0.1603, 0.0278, 0.3912],
#         [0.7607, 0.9292, 0.6421]], device='cuda:0')

# %%
# %%time
torch.matmul(tensor_1,tensor_2)
# Out:
# CPU times: total: 156 ms
# Wall time: 182 ms
# tensor([[-1.3119, -1.5812, -0.8458],
#         [-0.1863,  0.3216,  0.2190],
#         [-0.4978, -0.2786, -0.8340]], device='cuda:0')

# %%
tensor_1*tensor_2
# Out:
# tensor([[ 0.0723,  0.6000, -1.4923],
#         [ 0.1433, -0.0061, -0.2310],
#         [ 0.0494, -1.6166, -0.2031]], device='cuda:0')
