# %%
import torch 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device

# %%
tensor_1 = torch.randn(
    size=(3,3),
    device=device,
    requires_grad=True
)

tensor_2 = torch.rand_like(
    input=tensor_1
)

print(f"Tensor 1 : {tensor_1} \nTensor 2 : {tensor_2}")

# %%
# %%time
torch.matmul(tensor_1,tensor_2)

# %%
# %%time
tensor_1*tensor_2

# %%
tensor_1 + tensor_2

# %%
y = tensor_1**2
y

# %%
y.backward()
