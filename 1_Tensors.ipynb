# %%
import torch

# %%
def eval(tensor):
    print("="*30)
    print("Shape:",tensor.shape)
    print("Shape:",tensor.shape)

# %%
tensor_1  = torch.tensor(
    [1,2,3], 
)
print(tensor_1.shape)
print(tensor_1.)
